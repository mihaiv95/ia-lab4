# %%
# %matplotlib inline

# %% [markdown]
# A simple linear regression
# ===========================

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# x from 0 to 30
x = 30 * np.random.random((20, 1))

# y = a*x + b with noise
y = 0.5 * x + 1.0 + np.random.normal(size=x.shape)

# create a linear regression model
model = LinearRegression()
model.fit(x, y)

# predict y from the data
x_new = np.linspace(0, 30, 100)
y_new = model.predict(x_new[:, np.newaxis])

# plot the results
plt.figure(figsize=(4, 3))
ax = plt.axes()
ax.scatter(x, y)
ax.plot(x_new, y_new)

ax.set_xlabel('x')
ax.set_ylabel('y')

ax.axis('tight')


plt.show()

# %% [markdown]
# Exerciții
# =========

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
dataset = pd.read_csv('set1.txt', delim_whitespace=True)
x=dataset.iloc[:,0].values
y=dataset.iloc[:,1].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)
x_test = x_test.reshape(-1,1)
x_train = x_train.reshape(-1,1)
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
lin_reg_pred = lin_reg.predict(x_test)
print("Coefficients: ", lin_reg.coef_)
print("Intercept: ", lin_reg.intercept_)
print("Mean squared error: %.2f" % mean_squared_error(y_test, lin_reg_pred))
print('Variance score: %.2f' % r2_score(y_test, lin_reg_pred))
#plot
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_test, lin_reg_pred, color = 'blue')
plt.title('Linear Regression for set1.txt')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# Coefficients:  [1.86343801e+11]
# Intercept:  -2482715136860.9863
# Mean squared error: 5731450003215800427534614528.00
# Variance score: -0.25
# /var/folders/jw/yv3564gd34d57pv9_nmtf3540000gn/T/ipykernel_11554/1091358107.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataset = pd.read_csv('set1.txt', delim_whitespace=True)

# %%
dataset = pd.read_csv('set2.txt', header=None, names=['X', 'Y'], delim_whitespace=True)
x=dataset.iloc[:,0].values
y=dataset.iloc[:,1].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)
x_test = x_test.reshape(-1,1)
x_train = x_train.reshape(-1,1)
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
lin_reg_pred = lin_reg.predict(x_test)
print("Coefficients: ", lin_reg.coef_)
print("Intercept: ", lin_reg.intercept_)
print("Mean squared error: %.2f" % mean_squared_error(y_test, lin_reg_pred))
print('Variance score: %.2f' % r2_score(y_test, lin_reg_pred))
#plot
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_test, lin_reg_pred, color = 'blue')
plt.title('Linear Regression for set1.txt')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# Coefficients:  [5.10368227e+11]
# Intercept:  -5082633361491.312
# Mean squared error: 25917805950132379445100544.00
# Variance score: -0.13
# /var/folders/jw/yv3564gd34d57pv9_nmtf3540000gn/T/ipykernel_11554/1557492798.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataset = pd.read_csv('set2.txt', header=None, names=['X', 'Y'], delim_whitespace=True)

# %%
dataset = pd.read_csv('set3.txt', delim_whitespace=True, decimal=",")
x=dataset.iloc[:,0].values
y=dataset.iloc[:,1].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)
x_test = x_test.reshape(-1,1)
x_train = x_train.reshape(-1,1)
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
lin_reg_pred = lin_reg.predict(x_test)
print("Coefficients: ", lin_reg.coef_)
print("Intercept: ", lin_reg.intercept_)
print("Mean squared error: %.2f" % mean_squared_error(y_test, lin_reg_pred))
print('Variance score: %.2f' % r2_score(y_test, lin_reg_pred))
#plot
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_test, lin_reg_pred, color = 'blue')
plt.title('Linear Regression for set1.txt')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# Coefficients:  [1.09861229]
# Intercept:  -1.4210854715202004e-14
# Mean squared error: 0.00
# Variance score: 1.00
# /var/folders/jw/yv3564gd34d57pv9_nmtf3540000gn/T/ipykernel_11554/33306298.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dataset = pd.read_csv('set3.txt', delim_whitespace=True, decimal=",")
